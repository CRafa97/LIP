# %%
from lip import LIPImage
from lip.utils import RGB2gray
from skimage.data import astronaut, camera
import matplotlib.pyplot as plt

# %%
path1 = '/home/crafa/Downloads/abstract-yellow-leaves_2560x1440_xtrafondos.com.jpg'
path2= '/home/crafa/Downloads/attention.jpeg'

im = astronaut()
im = RGB2gray(im)
im = LIPImage(im)
cam = camera()
cam = RGB2gray(cam)
cam = LIPImage(255 - cam)

limg1 = LIPImage.from_file(path1, in_gray=False)
limg2 = LIPImage.from_file(path2, in_gray=False)

# %%
len([x for x in limg1.gray_levels.flat if x > 180])
# Out:
# 1066329

# %%
limg2
# Out:
# array([[ 95, 100, 108, ..., 124, 124, 124],
#        [ 93,  98, 106, ..., 124, 124, 124],
#        [ 93,  97, 105, ..., 124, 124, 124],
#        ...,
#        [148, 148, 148, ..., 112, 113, 114],
#        [146, 146, 145, ..., 111, 111, 111],
#        [144, 144, 143, ..., 109, 109, 109]], dtype=uint8)

# %%
im
# Out:
# array([[148, 105,  62, ..., 121, 116, 119],
#        [172, 141, 114, ..., 119, 116, 116],
#        [195, 178, 165, ..., 121, 117, 115],
#        ...,
#        [173, 173, 171, ...,   0,   0,   0],
#        [172, 170, 169, ...,   0,   1,   0],
#        [170, 169, 166, ...,   0,   1,   0]], dtype=uint8)

# %%
cam
# Out:
# array([[155, 156, 159, ..., 151, 151, 151],
#        [155, 156, 158, ..., 151, 151, 151],
#        [157, 156, 155, ..., 151, 151, 151],
#        ...,
#        [120, 122, 125, ..., 120, 112, 110],
#        [120, 122, 125, ..., 120, 112, 110],
#        [120, 122, 125, ..., 120, 112, 110]], dtype=uint8)

# %%
print(limg1.dim)
print(limg2.dim)
print(im.dim)
print(cam.dim)
# Out:
# (1440, 2560)
# (1350, 1080)
# (512, 512)
# (512, 512)

# %%
i1 = cam + im
print(i1.gray_levels)
plt.imshow(i1.gray_levels, cmap='gray')
# Out:
# [[ 46   4 220 ...  15  10  13]
#  [ 70  40  15 ...  13  10  10]
#  [ 95  77  63 ...  15  11   9]
#  ...
#  [ 36  38  39 ... 120 112 110]
#  [ 35  35  37 ... 120 112 110]
#  [ 33  34  34 ... 120 112 110]]
